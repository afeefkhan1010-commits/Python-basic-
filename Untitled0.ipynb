# %% [markdown]
# <a href="https://colab.research.google.com/github/afeefkhan1010-commits/Python-basic-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HELLO🌎")
# Out:
# HELLO🌎

# %%
name="afeef"
year="2026"
print("devil43", name)
print(year)
# Out:
# devil43 afeef
# 2026
